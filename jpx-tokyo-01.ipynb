# %%
import numpy as np
import pandas as pd
import plotly.express as px
import jpx_tokyo_market_prediction

train_path = "../input/jpx-tokyo-stock-exchange-prediction/train_files/"

# %%
dados = pd.read_csv(train_path + 'stock_prices.csv',index_col='Date', parse_dates=True).sort_values(by='Date')
dados.head(3)

# %%
colunas=['Open','High','Low','Close','Volume']
alvo=['Target']
dados = dados[~dados['Target'].isna()]

# %%
fig = px.line( x=dados.index, y=dados.Open, title='Time Series for variables')
fig.show()

# %%
fig = px.line( x=dados.index, y=dados.High, title='Time Series for variables')
fig.show()
